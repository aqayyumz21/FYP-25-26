# %%
from pathlib import Path
import pickle
import pandas as pd
import numpy as np

save_dir = Path(r"C:\Users\abdul\OneDrive - Nanyang Technological University\Desktop\Prof Gerfried Code Help")

with open(save_dir / "rf_shap_store.pkl", "rb") as f:
    rf_shap_store = pickle.load(f)

with open(save_dir / "rf_rank_store.pkl", "rb") as f:
    rf_rank_store = pickle.load(f)

with open(save_dir / "rf_X_shap.pkl", "rb") as f:
    X_shap_rf = pickle.load(f)

# %%
from pathlib import Path
import pickle
import joblib
import pandas as pd
import numpy as np

save_dir = Path(r"C:\Users\abdul\OneDrive - Nanyang Technological University\Desktop\Prof Gerfried Code Help")

with open(save_dir / "rf_shap_store.pkl", "rb") as f:
    rf_shap_store = pickle.load(f)

with open(save_dir / "rf_rank_store.pkl", "rb") as f:
    rf_rank_store = pickle.load(f)

with open(save_dir / "rf_X_shap.pkl", "rb") as f:
    X_shap_rf = pickle.load(f)

rf_best = joblib.load(save_dir / "rf_best.joblib")
svr_best = joblib.load(save_dir / "svr_best.joblib")

print("rf_shap_store type:", type(rf_shap_store))
print("rf_rank_store type:", type(rf_rank_store))
print("X_shap_rf type:", type(X_shap_rf))
print("rf_best type:", type(rf_best))
print("svr_best type:", type(svr_best))
# Out:
# C:\Users\abdul\anaconda3\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.8.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# rf_shap_store type: <class 'dict'>
# rf_rank_store type: <class 'dict'>
# X_shap_rf type: <class 'pandas.core.frame.DataFrame'>
# rf_best type: <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# svr_best type: <class 'sklearn.multioutput.MultiOutputRegressor'>
# C:\Users\abdul\anaconda3\Lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator RandomForestRegressor from version 1.8.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# ...

# %%
try:
    print("\nrf_shap_store preview:")
    display(rf_shap_store if isinstance(rf_shap_store, (pd.DataFrame, pd.Series)) else str(rf_shap_store)[:1000])
except:
    print(rf_shap_store)

try:
    print("\nrf_rank_store preview:")
    display(rf_rank_store if isinstance(rf_rank_store, (pd.DataFrame, pd.Series)) else str(rf_rank_store)[:1000])
except:
    print(rf_rank_store)

try:
    print("\nX_shap_rf preview:")
    display(X_shap_rf.head() if hasattr(X_shap_rf, "head") else X_shap_rf)
except:
    print(X_shap_rf)
# Out:
# rf_shap_store preview:
# ...

# %%
pip install shap
# Out:
# ...
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# ...
#    ---------------------------------------- 0.0/555.9 kB ? eta -:--:--
#    ---------------------------------------- 555.9/555.9 kB 8.1 MB/s  0:00:00
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# ...
#
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    ---------------------------------------- 2/2 [shap]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap
import matplotlib.pyplot as plt

shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
print("rf_shap_store keys:", rf_shap_store.keys())
print("rf_rank_store keys:", rf_rank_store.keys())
# Out:
# rf_shap_store keys: dict_keys(['Tensile_Strength_MPa', 'Elongation_Percent', 'Yield_Strength_MPa'])
# rf_rank_store keys: dict_keys(['Tensile_Strength_MPa', 'Elongation_Percent', 'Yield_Strength_MPa'])

# %%
for target in rf_shap_store:
    print(f"\n--- {target} ---")
    print("rf_shap_store[target] type:", type(rf_shap_store[target]))
    if hasattr(rf_shap_store[target], "shape"):
        print("shape:", rf_shap_store[target].shape)
    else:
        print(str(rf_shap_store[target])[:500])

for target in rf_rank_store:
    print(f"\n--- {target} ---")
    print("rf_rank_store[target] type:", type(rf_rank_store[target]))
    if hasattr(rf_rank_store[target], "shape"):
        print("shape:", rf_rank_store[target].shape)
        display(rf_rank_store[target].head())
    else:
        print(str(rf_rank_store[target])[:500])
# Out:
# --- Tensile_Strength_MPa ---
# rf_shap_store[target] type: <class 'numpy.ndarray'>
# shape: (3000, 27)
#
# --- Elongation_Percent ---
# rf_shap_store[target] type: <class 'numpy.ndarray'>
# shape: (3000, 27)
#
# --- Yield_Strength_MPa ---
# rf_shap_store[target] type: <class 'numpy.ndarray'>
# shape: (3000, 27)
#
# --- Tensile_Strength_MPa ---
# rf_rank_store[target] type: <class 'pandas.core.frame.DataFrame'>
# shape: (27, 4)
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 21             Ceq     84.718602    65.381824   84.718602
# 11              Nb     11.328661    10.470294   96.047263
# 14              Ti      9.456790    17.855847  105.504053
# 2   Annealing_Temp      4.889892     3.796878  110.393944
# 22             Pcm      3.861684     4.995995  114.255629
# --- Elongation_Percent ---
# rf_rank_store[target] type: <class 'pandas.core.frame.DataFrame'>
# shape: (27, 4)
#        Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# ...

# %%
target = "Tensile_Strength_MPa"
shap.summary_plot(rf_shap_store[target], X_shap_rf)
plt.show()

# %%
target = "Yield_Strength_MPa"
shap.summary_plot(rf_shap_store[target], X_shap_rf)
plt.show()

# %%
target = "Elongation_Percent"
shap.summary_plot(rf_shap_store[target], X_shap_rf)
plt.show()

# %%
target = "Tensile_Strength_MPa"
shap.summary_plot(rf_shap_store[target], X_shap_rf, plot_type="bar")
plt.show()

# %%
target = "Yield_Strength_MPa"
shap.summary_plot(rf_shap_store[target], X_shap_rf, plot_type="bar")
plt.show()

# %%
target = "Elongation_Percent"
shap.summary_plot(rf_shap_store[target], X_shap_rf, plot_type="bar")
plt.show()

# %%
display(rf_rank_store["Tensile_Strength_MPa"])
# Out:
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 21             Ceq     84.718602    65.381824   84.718602
# 11              Nb     11.328661    10.470294   96.047263
# 14              Ti      9.456790    17.855847  105.504053
# 2   Annealing_Temp      4.889892     3.796878  110.393944
# 22             Pcm      3.861684     4.995995  114.255629
# 3        Thickness      2.960635     2.943176  117.216264
# 1       Exist_Temp      1.982600     1.740033  119.198863
# 12              Al      1.291561     3.522871  120.490424
# 0     Furnace_Temp      1.105907     0.844588  121.596330
# 8               Cr      0.900031     2.213267  122.496361
# 24               N      0.858138     0.955676  123.354499
# 13    Acid Sol. Al      0.660718     1.962477  124.015217
# 4            Width      0.520385     0.640049  124.535601
# 9               Mo      0.424958     1.947146  124.960560
# 7               Ni      0.402765     0.559513  125.363324
# ...

# %%
display(rf_rank_store["Yield_Strength_MPa"])
# Out:
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 21             Ceq     85.151305    47.304577   85.151305
# 11              Nb     20.781364    16.202815  105.932670
# 14              Ti     12.439514    23.429530  118.372184
# 2   Annealing_Temp      6.591414     4.948749  124.963598
# 3        Thickness      5.631893     6.016220  130.595490
# 1       Exist_Temp      2.885903     2.597127  133.481394
# 22             Pcm      2.169230     3.060812  135.650624
# 0     Furnace_Temp      1.504049     1.187350  137.154672
# 24               N      1.089864     1.222854  138.244536
# 8               Cr      0.915000     2.915076  139.159535
# 4            Width      0.888645     1.158005  140.048180
# 9               Mo      0.629845     2.299056  140.678026
# 12              Al      0.554292     1.592788  141.232318
# 15               B      0.498906     0.951725  141.731224
# 10               V      0.478234     2.888803  142.209458
# ...

# %%
display(rf_rank_store["Elongation_Percent"])
# Out:
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 21             Ceq      5.459890     3.095886    5.459890
# 11              Nb      1.179954     1.097011    6.639844
# 14              Ti      0.971489     1.503894    7.611333
# 1       Exist_Temp      0.576135     0.419295    8.187468
# 3        Thickness      0.421596     0.438004    8.609064
# 2   Annealing_Temp      0.386803     0.333597    8.995867
# 22             Pcm      0.323782     0.282261    9.319649
# 4            Width      0.119028     0.138267    9.438677
# 12              Al      0.096990     0.225373    9.535667
# 24               N      0.072102     0.085340    9.607769
# 15               B      0.060549     0.118290    9.668318
# 8               Cr      0.053918     0.122585    9.722236
# 13    Acid Sol. Al      0.049367     0.130938    9.771604
# 0     Furnace_Temp      0.046477     0.055461    9.818080
# 6               Cu      0.042529     0.054808    9.860609
# ...

# %%
from pathlib import Path
import pickle
import pandas as pd
import numpy as np
import shap
import matplotlib.pyplot as plt

save_dir = Path(r"C:\Users\abdul\OneDrive - Nanyang Technological University\Desktop\Prof Gerfried Code Help")

with open(save_dir / "svr_shap_store.pkl", "rb") as f:
    svr_shap_store = pickle.load(f)

with open(save_dir / "svr_rank_store.pkl", "rb") as f:
    svr_rank_store = pickle.load(f)

with open(save_dir / "svr_X_eval.pkl", "rb") as f:
    X_eval_svr = pickle.load(f)

# %%
print("svr_shap_store type:", type(svr_shap_store))
print("svr_rank_store type:", type(svr_rank_store))
print("X_eval_svr type:", type(X_eval_svr))

print("svr_shap_store keys:", svr_shap_store.keys())
print("svr_rank_store keys:", svr_rank_store.keys())
# Out:
# svr_shap_store type: <class 'dict'>
# svr_rank_store type: <class 'dict'>
# X_eval_svr type: <class 'pandas.core.frame.DataFrame'>
# svr_shap_store keys: dict_keys(['Tensile_Strength_MPa', 'Elongation_Percent', 'Yield_Strength_MPa'])
# svr_rank_store keys: dict_keys(['Tensile_Strength_MPa', 'Elongation_Percent', 'Yield_Strength_MPa'])

# %%
for target in svr_shap_store:
    print(f"\n--- {target} ---")
    print("svr_shap_store[target] type:", type(svr_shap_store[target]))
    if hasattr(svr_shap_store[target], "shape"):
        print("shape:", svr_shap_store[target].shape)
    else:
        print(str(svr_shap_store[target])[:500])

for target in svr_rank_store:
    print(f"\n--- {target} ---")
    print("svr_rank_store[target] type:", type(svr_rank_store[target]))
    if hasattr(svr_rank_store[target], "shape"):
        print("shape:", svr_rank_store[target].shape)
        display(svr_rank_store[target].head())
    else:
        print(str(svr_rank_store[target])[:500])

print("\nX_eval_svr preview:")
display(X_eval_svr.head() if hasattr(X_eval_svr, "head") else X_eval_svr)
# Out:
# --- Tensile_Strength_MPa ---
# svr_shap_store[target] type: <class 'numpy.ndarray'>
# shape: (100, 27)
#
# --- Elongation_Percent ---
# svr_shap_store[target] type: <class 'numpy.ndarray'>
# shape: (100, 27)
#
# --- Yield_Strength_MPa ---
# svr_shap_store[target] type: <class 'numpy.ndarray'>
# shape: (100, 27)
#
# --- Tensile_Strength_MPa ---
# svr_rank_store[target] type: <class 'pandas.core.frame.DataFrame'>
# shape: (27, 4)
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 21             Ceq     31.148809    23.848305   31.148809
# 22             Pcm     27.911172    26.111103   59.059981
# 11              Nb     22.993673    13.560163   82.053654
# 14              Ti     12.030194    11.263648   94.083848
# 2   Annealing_Temp      8.248402     8.209544  102.332251
# --- Elongation_Percent ---
# svr_rank_store[target] type: <class 'pandas.core.frame.DataFrame'>
# shape: (27, 4)
#       Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# ...

# %%
target = "Tensile_Strength_MPa"
shap.summary_plot(svr_shap_store[target], X_eval_svr)
plt.show()

# %%
target = "Yield_Strength_MPa"
shap.summary_plot(svr_shap_store[target], X_eval_svr)
plt.show()

# %%
target = "Elongation_Percent"
shap.summary_plot(svr_shap_store[target], X_eval_svr)
plt.show()

# %%
target = "Tensile_Strength_MPa"
shap.summary_plot(svr_shap_store[target], X_eval_svr, plot_type="bar")
plt.show()

# %%
target = "Yield_Strength_MPa"
shap.summary_plot(svr_shap_store[target], X_eval_svr, plot_type="bar")
plt.show()

# %%
target = "Elongation_Percent"
shap.summary_plot(svr_shap_store[target], X_eval_svr, plot_type="bar")
plt.show()

# %%
display(svr_rank_store["Yield_Strength_MPa"])
# Out:
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 21             Ceq     36.331283    25.736355   36.331283
# 11              Nb     30.710330    17.744560   67.041613
# 22             Pcm     15.255705    10.297475   82.297318
# 14              Ti     14.964191    13.653368   97.261509
# 2   Annealing_Temp     10.248267     9.657705  107.509775
# 3        Thickness      7.516127     7.468446  115.025903
# 15               B      5.228692     4.369730  120.254594
# 1       Exist_Temp      4.045731     3.794340  124.300325
# 0     Furnace_Temp      3.726747     3.557764  128.027072
# 5                S      2.370235     2.196848  130.397306
# 19              Ca      1.973553     1.714243  132.370860
# 9               Mo      1.894894     0.758342  134.265754
# 24               N      1.732363     1.213682  135.998117
# 12              Al      1.480394     3.656376  137.478511
# 25               O      1.455682     1.686066  138.934193
# ...

# %%
display(svr_rank_store["Yield_Strength_MPa"])
# Out:
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 21             Ceq     36.331283    25.736355   36.331283
# 11              Nb     30.710330    17.744560   67.041613
# 22             Pcm     15.255705    10.297475   82.297318
# 14              Ti     14.964191    13.653368   97.261509
# 2   Annealing_Temp     10.248267     9.657705  107.509775
# 3        Thickness      7.516127     7.468446  115.025903
# 15               B      5.228692     4.369730  120.254594
# 1       Exist_Temp      4.045731     3.794340  124.300325
# 0     Furnace_Temp      3.726747     3.557764  128.027072
# 5                S      2.370235     2.196848  130.397306
# 19              Ca      1.973553     1.714243  132.370860
# 9               Mo      1.894894     0.758342  134.265754
# 24               N      1.732363     1.213682  135.998117
# 12              Al      1.480394     3.656376  137.478511
# 25               O      1.455682     1.686066  138.934193
# ...

# %%
display(svr_rank_store["Elongation_Percent"])
# Out:
#            Feature  Mean(|SHAP|)  Std(|SHAP|)  Cumulative
# 11              Nb      2.177735     1.242741    2.177735
# 22             Pcm      1.788432     1.374752    3.966167
# 21             Ceq      1.712529     1.991450    5.678697
# 14              Ti      1.691159     1.282232    7.369856
# 3        Thickness      0.863256     0.902723    8.233112
# 2   Annealing_Temp      0.854463     0.767193    9.087576
# 1       Exist_Temp      0.850047     0.702480    9.937623
# 8               Cr      0.293910     0.308634   10.231533
# 4            Width      0.275614     0.285403   10.507147
# 0     Furnace_Temp      0.242452     0.271810   10.749598
# 15               B      0.238491     0.211530   10.988089
# 17              As      0.236619     0.339957   11.224709
# 5                S      0.217905     0.193004   11.442613
# 18              Zr      0.194450     0.168301   11.637064
# 16              Sn      0.183879     0.223929   11.820942
# ...
